# %% [markdown]
# <a href="https://colab.research.google.com/github/orcunmadran/hu-bby261-2024/blob/main/webSpider002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Web Örümceği ikinci sürüm - 17.10.2024

# %%
# Uygulamada kullanılacak kütüphaneler
import ipywidgets as arayuz
import requests as getir
from bs4 import BeautifulSoup as analiz

# %%
# @title
# Veri toplama araçları

# Uygulama başlık
baslik = arayuz.HTML(value="<h1>::: Web Örümceği :::</h1>")
display(baslik)

# Uygulama ara başlık
araBaslik = arayuz.HTML(value="<h2>Tarama verisi oluştur:</h2>")
display(araBaslik)

# Sonuçlar ara başlık
araSonuc = arayuz.HTML(value="<h2>Tarama sonuçları:</h2>")

#Uygulama açıklama
aciklama = arayuz.HTML(value="<p>Web taraması için başlangıç adresi olarak belirlemek istediğiniz URL'yi giriniz. URL https ya da http ön eki ile başlamalıdır. Tarama seviyesini istediğiniz bir değere ayarlayınız ve taramayı başlat düğmesine tıklayınız:</p>")
display(aciklama)

# Tarama başlangıç adresi
url = arayuz.Text(value="https://", description="")
display(url)

# Tarama için seviye belirleyici
level = arayuz.IntSlider(min=1, max=5, step=1, value=2)
display(level)

# Tarama işlemine başlanılması için buton
buton = arayuz.Button(description="Taramayı başlat!")
display(buton)

# Arayüzde kullanılan ayiricilar
ayirici = arayuz.HTML(value="<hr>")
display(ayirici)

def taramaBasla(b):

    #Tarama verisi topla ve göster
    adres = url.value
    print("Başlangıç adresi: " + adres)
    seviye = level.value
    print("Tarama seviyesi: " + str(seviye))
    display(ayirici)

    #Tarama verisini getir
    response = getir.get(adres)
    html = response.content
    print(html)
    display(ayirici)

    # BeautifulSoup nesnesi oluştur
    soup = analiz(html, "html.parser")

    # Başlığı bul ve yazdır
    sayfaBaslik = soup.find("title").text
    display(araSonuc)
    kayitBaslik = sayfaBaslik + " - " + adres
    print(kayitBaslik)
    display(ayirici)

    # Sayfadaki tüm bağlantıları bul
    linkler = soup.find_all("a")
    kayitLink = ""
    for link in linkler:
      kayitLink += link.get("href") + " ||| "

    print(kayitLink)

    display(ayirici)

    #Dosya yazma işlemleri
    with open("tarama_verileri.txt", "a", encoding="utf-8") as dosya:
      dosya.write(kayitBaslik + " <<>> " + kayitLink + "\n")  # Başlığı yaz

    print("Tarama tamamlandı ve dosya kaydedildi!")

buton.on_click(taramaBasla)
# Out:
# HTML(value='<h1>::: Web Örümceği :::</h1>')
# HTML(value='<h2>Tarama verisi oluştur:</h2>')
# HTML(value="<p>Web taraması için başlangıç adresi olarak belirlemek istediğiniz URL'yi giriniz. URL https ya d…
# Text(value='https://')
# IntSlider(value=2, max=5, min=1)
# Button(description='Taramayı başlat!', style=ButtonStyle())
# HTML(value='<hr>')
# Başlangıç adresi: https://madran.net
# Tarama seviyesi: 2
# HTML(value='<hr>')
# b'<!DOCTYPE html>\n<html lang="tr">\n<head>\n\t<meta charset="UTF-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0" >\n\t<link rel="profile" href="http://gmpg.org/xfn/11" />\n\t<title>R. Or\xc3\xa7un Madran &#8211; Akademisyen | Aktivist | Triatlet</title>\n<meta name=\'robots\' content=\'max-image-preview:large\' />\n<link rel=\'dns-prefetch\' href=\'//stats.wp.com\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//c0.wp.com\' />\n<link rel=\'dns-prefetch\' href=\'//i0.wp.com\' />\n<link rel=\'dns-prefetch\' href=\'//www.googletagmanager.com\' />\n<link rel="alternate" type="application/rss+xml" title="R. Or\xc3\xa7un Madran &raquo; ak\xc4\xb1\xc5\x9f\xc4\xb1" href="https://madran.net/feed/" />\n<link rel="alternate" type="application/rss+xml" title="R. Or\xc3\xa7un Madran &raquo; yorum ak\xc4\xb1\xc5\x9f\xc4\xb1" href="https://madran.net/comments/feed/" />\n<script type="text/javascript">\n/* <![CDATA[ */\nwindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/15.0.3\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/15.0.3\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/madran.net\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=6.6.2"}};\n/*! This file is auto-generated */\n!function(i,n){var o,s,e;function c(e){try{var t={supportTests:e,timestamp:(new Date).valueOf()};sessionStorage.setItem(o,JSON.stringify(t))}catch(e){}}function p(e,t,n){e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(t,0,0);var t=new Uint32Array(e.getImageData(0,0,e.canvas.width,e.canvas.height).data),r=(e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(n,0,0),new Uint32Array(e.getImageData(0,0,e.canvas.width,e.canvas.height).data));return t.every(function(e,t){return e===r[t]})}function u(e,t,n){switch(t){case"flag":return n(e,"\\ud83c\\udff3\\ufe0f\\u200d\\u26a7\\ufe0f","\\ud83c\\udff3\\ufe0f\\u200b\\u26a7\\ufe0f")?!1:!n(e,"\\ud83c\\uddfa\\ud83c\\uddf3","\\ud83c\\uddfa\\u200b\\ud83c\\uddf3")&&!n(e,"\\ud83c\\udff4\\udb40\\udc67\\udb40\\udc62\\udb40\\udc65\\udb40\\udc6e\\udb40\\udc67\\udb40\\udc7f","\\ud83c\\udff4\\u200b\\udb40\\udc67\\u200b\\udb40\\udc62\\u200b\\udb40\\udc65\\u200b\\udb40\\udc6e\\u200b\\udb40\\udc67\\u200b\\udb40\\udc7f");case"emoji":return!n(e,"\\ud83d\\udc26\\u200d\\u2b1b","\\ud83d\\udc26\\u200b\\u2b1b")}return!1}function f(e,t,n){var r="undefined"!=typeof WorkerGlobalScope&&self instanceof WorkerGlobalScope?new OffscreenCanvas(300,150):i.createElement("canvas"),a=r.getContext("2d",{willReadFrequently:!0}),o=(a.textBaseline="top",a.font="600 32px Arial",{});return e.forEach(function(e){o[e]=t(a,e,n)}),o}function t(e){var t=i.createElement("script");t.src=e,t.defer=!0,i.head.appendChild(t)}"undefined"!=typeof Promise&&(o="wpEmojiSettingsSupports",s=["flag","emoji"],n.supports={everything:!0,everythingExceptFlag:!0},e=new Promise(function(e){i.addEventListener("DOMContentLoaded",e,{once:!0})}),new Promise(function(t){var n=function(){try{var e=JSON.parse(sessionStorage.getItem(o));if("object"==typeof e&&"number"==typeof e.timestamp&&(new Date).valueOf()<e.timestamp+604800&&"object"==typeof e.supportTests)return e.supportTests}catch(e){}return null}();if(!n){if("undefined"!=typeof Worker&&"undefined"!=typeof OffscreenCanvas&&"undefined"!=typeof URL&&URL.createObjectURL&&"undefined"!=typeof Blob)try{var e="postMessage("+f.toString()+"("+[JSON.stringify(s),u.toString(),p.toString()].join(",")+"));",r=new Blob([e],{type:"text/javascript"}),a=new Worker(URL.createObjectURL(r),{name:"wpTestEmojiSupports"});return void(a.onmessage=function(e){c(n=e.data),a.terminate(),t(n)})}catch(e){}c(n=f(s,u,p))}t(n)}).then(function(e){for(var t in e)n.supports[t]=e[t],n.supports.everything=n.supports.everything&&n.supports[t],"flag"!==t&&(n.supports.everythingExceptFlag=n.supports.everythingExceptFlag&&n.supports[t]);n.supports.everythingExceptFlag=n.supports.everythingExceptFlag&&! ...
# HTML(value='<hr>')
# HTML(value='<h2>Tarama sonuçları:</h2>')
# R. Orçun Madran – Akademisyen | Aktivist | Triatlet - https://madran.net
# HTML(value='<hr>')
# #content ||| https://madran.net/ ||| #search-container ||| https://madran.net/ ||| https://twitter.com/orcunmadran ||| https://www.youtube.com/orcunmadran ||| https://www.instagram.com/orcunmadran/ ||| https://www.facebook.com/orcunmadran/ ||| https://www.linkedin.com/in/omadran/ ||| https://www.strava.com/athletes/8784393 ||| http://www.madran.net ||| https://madran.net/orcun_madran/ ||| # ||| https://madran.net/akademik-yayinlar/ ||| https://podcasters.spotify.com/pod/show/orcunmadran ||| https://madran.net/category/akademiden-notlar/ ||| https://podcasters.spotify.com/pod/show/akademiden-notlar ||| # ||| https://madran.net/bby-162-programlama-ve-algoritmalar/ ||| https://madran.net/bby-261-ileri-programlama/ ||| https://madran.net/bby-262-web-tasarimi/ ||| https://madran.net/bby-265-elektronik-yayincilik-2015/ ||| https://madran.net/bby-361-veri-tabani-yonetim-sistemleri/ ||| https://madran.net/bby-464-semantic-information-management/ ||| https://madran.net/bote-205-ogretim-teknolojileri-ve-materyal-gelistirme/ ||| https://madran.net/btu-100-bilgisayar-teknolojileri-ve-uygulamalarina-giris/ ||| # ||| https://madran.net/bisiklet-akademisi/ ||| https://madran.net/muzik_diskografi/ ||| https://madran.net/english/ ||| # ||
n<head>\n\t<meta charset="UTF-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t<link rel="profile" href="https://gmpg.org/xfn/11">\n\t\t<script>(function(html){html.className = html.className.replace(/\\bno-js\\b/,\'js\')})(document.documentElement);</script>\n<title>A\xc3\xa7\xc4\xb1k Bilim T\xc3\xbcrkiye</title>\n<meta name=\'robots\' content=\'max-image-preview:large\' />\n<link rel=\'dns-prefetch\' href=\'//stats.wp.com\' />\n<link rel=\'dns-prefetch\' href=\'//i0.wp.com\' />\n<link rel=\'dns-prefetch\' href=\'//c0.wp.com\' />\n<link rel="alternate" type="application/rss+xml" title="A\xc3\xa7\xc4\xb1k Bilim T\xc3\xbcrkiye &raquo; ak\xc4\xb1\xc5\x9f\xc4\xb1" href="https://acikbilim.org/feed/" />\n<link rel="alternate" type="application/rss+xml" title="A\xc3\xa7\xc4\xb1k Bilim T\xc3\xbcrkiye &raquo; yorum ak\xc4\xb1\xc5\x9f\xc4\xb1" href="https://acikbilim.org/comments/feed/" />\n<script>\nwindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/15.0.3\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/15.0.3\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/acikbilim.org\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=6.6.2"}};\n/*! This file is auto-generated */\n!function(i,n){var o,s,e;function c(e){try{var t={supportTests:e,timestamp:(new Date).valueOf()};sessionStorage.setItem(o,JSON.stringify(t))}catch(e){}}function p(e,t,n){e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(t,0,0);var t=new Uint32Array(e.getImageData(0,0,e.canvas.width,e.canvas.height).data),r=(e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(n,0,0),new Uint32Array(e.getImageData(0,0,e.canvas.width,e.canvas.height).data));return t.every(function(e,t){return e===r[t]})}function u(e,t,n){switch(t){case"flag":return n(e,"\\ud83c\\udff3\\ufe0f\\u200d\\u26a7\\ufe0f","\\ud83c\\udff3\\ufe0f\\u200b\\u26a7\\ufe0f")?!1:!n(e,"\\ud83c\\uddfa\\ud83c\\uddf3","\\ud83c\\uddfa\\u200b\\ud83c\\uddf3")&&!n(e,"\\ud83c\\udff4\\udb40\\udc67\\udb40\\udc62\\udb40\\udc65\\udb40\\udc6e\\udb40\\udc67\\udb40\\udc7f","\\ud83c\\udff4\\u200b\\udb40\\udc67\\u200b\\udb40\\udc62\\u200b\\udb40\\udc65\\u200b\\udb40\\udc6e\\u200b\\udb40\\udc67\\u200b\\udb40\\udc7f");case"emoji":return!n(e,"\\ud83d\\udc26\\u200d\\u2b1b","\\ud83d\\udc26\\u200b\\u2b1b")}return!1}function f(e,t,n){var r="undefined"!=typeof WorkerGlobalScope&&self instanceof WorkerGlobalScope?new OffscreenCanvas(300,150):i.createElement("canvas"),a=r.getContext("2d",{willReadFrequently:!0}),o=(a.textBaseline="top",a.font="600 32px Arial",{});return e.forEach(function(e){o[e]=t(a,e,n)}),o}function t(e){var t=i.createElement("script");t.src=e,t.defer=!0,i.head.appendChild(t)}"undefined"!=typeof Promise&&(o="wpEmojiSettingsSupports",s=["flag","emoji"],n.supports={everything:!0,everythingExceptFlag:!0},e=new Promise(function(e){i.addEventListener("DOMContentLoaded",e,{once:!0})}),new Promise(function(t){var n=function(){try{var e=JSON.parse(sessionStorage.getItem(o));if("object"==typeof e&&"number"==typeof e.timestamp&&(new Date).valueOf()<e.timestamp+604800&&"object"==typeof e.supportTests)return e.supportTests}catch(e){}return null}();if(!n){if("undefined"!=typeof Worker&&"undefined"!=typeof OffscreenCanvas&&"undefined"!=typeof URL&&URL.createObjectURL&&"undefined"!=typeof Blob)try{var e="postMessage("+f.toString()+"("+[JSON.stringify(s),u.toString(),p.toString()].join(",")+"));",r=new Blob([e],{type:"text/javascript"}),a=new Worker(URL.createObjectURL(r),{name:"wpTestEmojiSupports"});return void(a.onmessage=function(e){c(n=e.data),a.terminate(),t(n)})}catch(e){}c(n=f(s,u,p))}t(n)}).then(function(e){for(var t in e)n.supports[t]=e[t],n.supports.everything=n.supports.everything&&n.supports[t],"flag"!==t&&(n.supports.everythingExceptFlag=n.supports.everythingExceptFlag&&n.supports[t]);n.supports.everythingExceptFlag=n.supports.everythingExceptFlag&&!n.supports.flag ...
# HTML(value='<hr>')
# HTML(value='<h2>Tarama sonuçları:</h2>')
# Açık Bilim Türkiye - https://acikbilim.org
# HTML(value='<hr>')
# #content ||| https://acikbilim.org/ ||| http://acikbilim.org ||| # ||| https://ab2022.acikbilim.org/ ||| http://ab2019.acikbilim.org/ ||| # ||| http://zirve2018.acikbilim.org ||| # ||| https://ae2024.acikerisim.org/ ||| https://ae2023.acikerisim.org/ ||| https://ae2022.acikerisim.org/ ||| https://ae2021.acikerisim.org/ ||| http://ae2020.acikerisim.org/ ||| http://ae2017.acikerisim.org ||| http://ae2016.acikerisim.org ||| http://ae2015.acikerisim.org ||| http://ae2014.acikerisim.org ||| http://ae2013.acikerisim.org ||| http://ae2012.acikerisim.org ||| https://acikbilim.org/iletisim/ ||| https://acikbilim.org/uluslararasi-acik-erisim-haftasi-2024/ ||| https://ae2024.acikerisim.org/ ||| https://acikbilim.org/author/wpadminacikbilimorg/ ||| https://acikbilim.org/uluslararasi-acik-erisim-haftasi-